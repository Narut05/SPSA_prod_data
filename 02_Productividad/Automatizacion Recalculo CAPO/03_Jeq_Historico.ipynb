# %% [markdown]
# ### 00 LIBRERIAS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from glob import glob
# Aplicar configuraciones de visualización total de Pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)

from pathlib import Path
import glob

import warnings
warnings.filterwarnings("ignore")
import plotly.express as px

# %% [markdown]
# ### 01 EXTRACT

# %%
ruta_locales = r"bk\input\dim\dim_locales.xlsx"
df_locales = pd.read_excel(ruta_locales)

# %%
ruta_puestos = r"bk\input\dim\Mapeo_Puestos_Dotacion_Tipos.xlsx"
df_puestos = pd.read_excel(ruta_puestos)

# %%
ruta_secciones = r"bk\input\dim\dim_secciones.xlsx"
df_secciones = pd.read_excel(ruta_secciones)

# %%
lista_excel = ["HrsReales_Export_202401-202506.xlsx", "HrsRealesLite_202512.xlsx"]
lista_csv = ["HrsRealesLite_202507.csv","HrsRealesLite_202508.csv", "HrsRealesLite_202509.csv", "HrsRealesLite_202510.csv", "HrsRealesLite_202511.csv", "HrsRealesLite_202601v2.csv",
             "HrsRealesLite_202602.csv", "HrsRealesLite_202603.csv"]
lista_csv2 = ["Hrs_reales_202604.csv", "Hrs_reales_202605.csv", "Hrs_reales_20260607.csv"]
ruta = r"bk\input\bd_jeq"

# %%
rutas_completas = [os.path.join(ruta, archivo) for archivo in lista_excel]
dfs = [pd.read_excel(p) for p in rutas_completas]
df_jeq_1 = pd.concat(dfs, ignore_index=True)

# %%
df_jeq_1
# Out:
#                         Name        Date modified                  LOCAL  \
# 0       Hrs_reales202401.csv  2025-08-12 14:55:19  CFR PVEA AVENTURA SJL
# 1       Hrs_reales202401.csv  2025-08-12 14:55:19      CFR PVEA AREQUIPA
# 2       Hrs_reales202401.csv  2025-08-12 14:55:19  CFR PVEA AVENTURA SJL
# 3       Hrs_reales202401.csv  2025-08-12 14:55:19     CFR PVEA BOLICHERA
# 4       Hrs_reales202401.csv  2025-08-12 14:55:19     CFR PVEA BOLICHERA
# ...                      ...                  ...                    ...
# 205224  Hrs_reales202512.csv  2026-01-07T20:32:02         SPO TARAPOTO 2
# 205225  Hrs_reales202512.csv  2026-01-07T20:32:02         SPO TARAPOTO 2
# 205226  Hrs_reales202512.csv  2026-01-07T20:32:02         SPO TARAPOTO 2
# 205227  Hrs_reales202512.csv  2026-01-07T20:32:02         SPO TARAPOTO 2
# 205228  Hrs_reales202512.csv  2026-01-07T20:32:02         SPO TARAPOTO 2
#
#         SECCION       DNI                                NOMBRE  \
# 0         CAJAS  71385932  BUSTAMANTE FUENTES, DARLYNE MILAGROS
# 1         CAJAS  76293715              CUSI LIPA, ISAAC RICARDO
# 2         CAJAS  70836619                  URQUIA AYBAR, YASSER
# 3         CAJAS  71053597  LUNA SHUPINGAHUA, MARYCIELO MILAGROS
# 4         CAJAS  70404776             ALARCON BACA, JOSE CARLOS
# ...         ...       ...                                   ...
# 205224  ELECTRO  76770638                   CHUMBE PIÑA, TRUMAN
# 205225  ELECTRO  41871365                  DIAZ PIZANGO, SILVIA
# 205226  ELECTRO  71104100         PEREZ BANCES, DAVID SEBASTIAN
# 205227  ELECTRO  72525565            TANGOA PISCO, LUIS ENRIQUE
# 205228  ELECTRO  73876431      TELLO FASANANDO, SHARON YESABELL
#
#                             PUESTO      FECHA  HRS_REAL
# 0         CFR CAJERO 6X1 2DO TURNO 2024-01-01      97.5
# 1         CFR CAJERO 6X1 2DO TURNO 2024-01-01      97.5
# 2         CFR CAJERO 6X1 2DO TURNO 2024-01-01      97.5
# 3         CFR CAJERO 6X1 2DO TURNO 2024-01-01      97.5
# 4         CFR CAJERO 6X1 2DO TURNO 2024-01-01      97.5
# ...                            ...        ...       ...
# 205224  SPO VENDEDOR PART TIME 5X2 2025-12-01      94.5
# 205225  SPO VENDEDOR PART TIME 5X2 2025-12-01      40.5
# 205226  SPO VENDEDOR PART TIME 5X2 2025-12-01      99.0
# 205227  SPO VENDEDOR PART TIME 5X2 2025-12-01      40.5
# 205228  SPO VENDEDOR PART TIME 5X2 2025-12-01      85.5
#
# [205229 rows x 9 columns]

# %%
rutas_completas = [os.path.join(ruta, archivo) for archivo in lista_csv]

# %%
rutas_completas
# Out:
# ['bk\\input\\bd_jeq\\HrsRealesLite_202507.csv',
#  'bk\\input\\bd_jeq\\HrsRealesLite_202508.csv',
#  'bk\\input\\bd_jeq\\HrsRealesLite_202509.csv',
#  'bk\\input\\bd_jeq\\HrsRealesLite_202510.csv',
#  'bk\\input\\bd_jeq\\HrsRealesLite_202511.csv',
#  'bk\\input\\bd_jeq\\HrsRealesLite_202601v2.csv',
#  'bk\\input\\bd_jeq\\HrsRealesLite_202602.csv',
#  'bk\\input\\bd_jeq\\HrsRealesLite_202603.csv']

# %%
dfs = [pd.read_csv(p, sep=",") for p in rutas_completas]
df_jeq_2 = pd.concat(dfs, ignore_index=True)

# %%
df_jeq_2
# Out:
#            BD_HrsReal[Name] BD_HrsReal[Date modified]  Tiempo[_Periodo01]  \
# 0      Hrs_reales202507.csv       2025-08-12T09:52:15            20250701
# 1      Hrs_reales202507.csv       2025-08-12T09:52:15            20250701
# 2      Hrs_reales202507.csv       2025-08-12T09:52:15            20250701
# 3      Hrs_reales202507.csv       2025-08-12T09:52:15            20250701
# 4      Hrs_reales202507.csv       2025-08-12T09:52:15            20250701
# ...                     ...                       ...                 ...
# 87979  Hrs_reales202603.csv       2026-04-08T13:54:39            20260301
# 87980  Hrs_reales202603.csv       2026-04-08T13:54:39            20260301
# 87981  Hrs_reales202603.csv       2026-04-08T13:54:39            20260301
# 87982  Hrs_reales202603.csv       2026-04-08T13:54:39            20260301
# 87983  Hrs_reales202603.csv       2026-04-08T13:54:39            20260301
#
#           BD_HrsReal[LOCAL] BD_HrsReal[SECCION]          BD_HrsReal[PUESTO]  \
# 0      CFR PVEA SANTA CLARA               CAJAS    CFR CAJERO 5X2 2DO TURNO
# 1      CFR PVEA SANTA CLARA               CAJAS    CFR CAJERO 5X2 2DO TURNO
# 2      CFR PVEA SANTA CLARA               CAJAS    CFR CAJERO 5X2 2DO TURNO
# 3      CFR PVEA SANTA CLARA               CAJAS    CFR CAJERO 5X2 2DO TURNO
# 4      CFR PVEA SANTA CLARA               CAJAS    CFR CAJERO 5X2 2DO TURNO
# ...                     ...                 ...                         ...
# 87979        SPO TARAPOTO 2             ELECTRO                SPO VENDEDOR
# 87980        SPO TARAPOTO 2             ELECTRO                SPO VENDEDOR
# 87981        SPO TARAPOTO 2             ELECTRO  SPO VENDEDOR PART TIME 5X2
# 87982        SPO TARAPOTO 2             ELECTRO  SPO VENDEDOR PART TIME 5X2
# 87983        SPO TARAPOTO 2             ELECTRO  SPO VENDEDOR PART TIME 5X2
#
#        BD_HrsReal[DNI]                 BD_HrsReal[NOMBRE]  [HRS_REAL]
# 0             73257589      CONDOR PONCE, FERNANDO WILSON       99.00
# 1             73615663         HUAMAN DELA CRUZ, MARICRUZ       99.00
# 2             73684401       ARPI BRICENO, TIFFANI LISETH       94.50
# 3             74540974      SERRANO BARRENA, MILENE PAOLA       94.50
# 4             74625029   AQUINO CORCUERA, LIZET ALEXANDRA       99.00
# ...                ...                                ...         ...
# 87979         48333031  GONZALES NITIVIRI, CARLOS ALBERTO      227.44
# 87980         40276794     SUAREZ JIMENEZ, DANIEL EDUARDO      216.45
# 87981         76770638                CHUMBE PIÑA, TRUMAN       94.50
# 87982         72525565         TANGOA PISCO, LUIS ENRIQUE       99.00
# 87983         73876431   TELLO FASANANDO, SHARON YESABELL      103.50
#
# [87984 rows x 9 columns]

# %%
rutas_completas = [os.path.join(ruta, archivo) for archivo in lista_csv2]
dfs = [pd.read_csv(p, sep=";") for p in rutas_completas]
df_jeq_3 = pd.concat(dfs, ignore_index=True)

# %%
df_jeq_1["_Periodo"] = (df_jeq_1["FECHA"].dt.year).astype(str) + (df_jeq_1["FECHA"].dt.month).astype(str).str.zfill(2)

# %%
df_jeq_2["LOCAL"] = df_jeq_2["BD_HrsReal[LOCAL]"]
df_jeq_2["SECCION"] = df_jeq_2["BD_HrsReal[SECCION]"]
df_jeq_2["DNI"] = df_jeq_2["BD_HrsReal[DNI]"]
df_jeq_2["NOMBRE"] = df_jeq_2["BD_HrsReal[NOMBRE]"]
df_jeq_2["PUESTO"] = df_jeq_2["BD_HrsReal[PUESTO]"]
df_jeq_2["_Periodo"] = df_jeq_2["Tiempo[_Periodo01]"].astype(str).str[0:6]
df_jeq_2["HRS_REAL"] = df_jeq_2["[HRS_REAL]"]

df_jeq_2[['LOCAL', 'SECCION', 'DNI', 'NOMBRE', 'PUESTO', '_Periodo', 'HRS_REAL']].head(2)
# Out:
#                   LOCAL SECCION       DNI                         NOMBRE  \
# 0  CFR PVEA SANTA CLARA   CAJAS  73257589  CONDOR PONCE, FERNANDO WILSON
# 1  CFR PVEA SANTA CLARA   CAJAS  73615663     HUAMAN DELA CRUZ, MARICRUZ
#
#                      PUESTO _Periodo  HRS_REAL
# 0  CFR CAJERO 5X2 2DO TURNO   202507      99.0
# 1  CFR CAJERO 5X2 2DO TURNO   202507      99.0

# %%
df_jeq_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1244648 entries, 0 to 1244647
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   LOCAL          1244648 non-null  object
#  1   SECCION        1244648 non-null  object
#  2   DNI            1244648 non-null  int64
#  3   NOMBRE         1244648 non-null  object
#  4   PUESTO         1244648 non-null  object
#  5   FECHA          1244648 non-null  object
#  6   HRS_REAL       1244648 non-null  float64
#  7   HRS_REAL_HHMM  1244648 non-null  object
#  8   CODIGO LOCAL   1244648 non-null  int64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 85.5+ MB

# %%
df_jeq_3["FECHA"] = pd.to_datetime(df_jeq_3["FECHA"], format="%d/%m/%Y")
df_jeq_3["_Periodo"] = (df_jeq_3["FECHA"].dt.year).astype(str) + (df_jeq_3["FECHA"].dt.month).astype(str).str.zfill(2)
df_jeq_3[['LOCAL', 'SECCION', 'DNI', 'NOMBRE', 'PUESTO', '_Periodo', 'HRS_REAL']].head(2)
# Out:
#                           LOCAL         SECCION       DNI  \
# 0  MAKRO SAN JUAN DE MIRAFLORES       ABARROTES  76766474
# 1             MASS MS JASPES 20  MULTIFUNCIONAL  61215764
#
#                          NOMBRE                        PUESTO _Periodo  \
# 0      LUNA RAMOS, LUCIA KARINA   MAKRO AUXILIAR DE ABARROTES   202604
# 1  ABARCA CUSTODIO, JUAN MANUEL  MASS OPERADOR DE TIENDA MASS   202604
#
#    HRS_REAL
# 0       8.0
# 1       7.9

# %%
df_jeq_final = pd.concat([df_jeq_1[['LOCAL', 'SECCION', 'DNI', 'NOMBRE', 'PUESTO','_Periodo', 'HRS_REAL']], df_jeq_2[['LOCAL', 'SECCION', 'DNI', 'NOMBRE', 'PUESTO', '_Periodo', 'HRS_REAL']],
                          df_jeq_3[['LOCAL', 'SECCION', 'DNI', 'NOMBRE', 'PUESTO', '_Periodo', 'HRS_REAL']]])

# %%
df_jeq_final
# Out:
#                          LOCAL SECCION       DNI  \
# 0        CFR PVEA AVENTURA SJL   CAJAS  71385932
# 1            CFR PVEA AREQUIPA   CAJAS  76293715
# 2        CFR PVEA AVENTURA SJL   CAJAS  70836619
# 3           CFR PVEA BOLICHERA   CAJAS  71053597
# 4           CFR PVEA BOLICHERA   CAJAS  70404776
# ...                        ...     ...       ...
# 1244643           SPO PVO JAEN    SALA  75075495
# 1244644           SPO PVO JAEN    SALA  75075495
# 1244645           SPO PVO JAEN    SALA  75159455
# 1244646           SPO PVO JAEN    SALA  75159455
# 1244647           SPO PVO JAEN    SALA  75159455
#
#                                        NOMBRE  \
# 0        BUSTAMANTE FUENTES, DARLYNE MILAGROS
# 1                    CUSI LIPA, ISAAC RICARDO
# 2                        URQUIA AYBAR, YASSER
# 3        LUNA SHUPINGAHUA, MARYCIELO MILAGROS
# 4                   ALARCON BACA, JOSE CARLOS
# ...                                       ...
# 1244643         LORENZO RAMIREZ, JHON WILLIAM
# 1244644         LORENZO RAMIREZ, JHON WILLIAM
# 1244645           BURGA MAJUAN, KATIA MILUSKA
# 1244646           BURGA MAJUAN, KATIA MILUSKA
# 1244647           BURGA MAJUAN, KATIA MILUSKA
#
#                                          PUESTO _Periodo  HRS_REAL
# 0                      CFR CAJERO 6X1 2DO TURNO   202401     97.50
# 1                      CFR CAJERO 6X1 2DO TURNO   202401     97.50
# 2                      CFR CAJERO 6X1 2DO TURNO   202401     97.50
# 3                      CFR CAJERO 6X1 2DO TURNO   202401     97.50
# 4                      CFR CAJERO 6X1 2DO TURNO   202401     97.50
# ...                                         ...      ...       ...
# 1244643  SPO REPRES. DE SERVICIOS 5X2 2DO TURNO   202606      4.50
# 1244644  SPO REPRES. DE SERVICIOS 5X2 2DO TURNO   202606      4.50
# 1244645                SPO REPRES. DE SERVICIOS   202606      9.38
# 1244646                SPO REPRES. DE SERVICIOS   202606     10.35
# 1244647                SPO REPRES. DE SERVICIOS   202606      8.18
#
# [1537861 rows x 7 columns]

# %% [markdown]
# ### 02 TRANSFORM

# %%
df_jeq_final.head(1)
# Out:
#                    LOCAL SECCION       DNI  \
# 0  CFR PVEA AVENTURA SJL   CAJAS  71385932
#
#                                  NOMBRE                    PUESTO _Periodo  \
# 0  BUSTAMANTE FUENTES, DARLYNE MILAGROS  CFR CAJERO 6X1 2DO TURNO   202401
#
#    HRS_REAL
# 0      97.5

# %%
def clean_text_series(series):
    # .str accede a las operaciones de cadena de forma vectorizada a nivel de C
    return (
        series.astype(str)
        .str.upper()
        .str.normalize("NFKD")
        .str.encode("ascii", errors="ignore")
        .str.decode("utf-8")
        .str.strip()
    )

# %%
df_jeq_final1 = df_jeq_final.merge(df_locales[["nombre_Kr", "codigo_local", "Tienda"]], left_on="LOCAL", right_on="nombre_Kr", how="left")
df_jeq_final2 = df_jeq_final1[~df_jeq_final1["nombre_Kr"].isnull()]
df_jeq_final3  = df_jeq_final2.groupby(["_Periodo", "codigo_local", "Tienda", "PUESTO", "SECCION"])["HRS_REAL"].sum().reset_index()

df_puestos_clean = df_puestos[
    ["Departamento", "Nombre de Posición", "Grupo_Area"]
].copy()

# Normalizamos las llaves de cruce en el maestro
df_puestos_clean["Departamento"] = clean_text_series(
    df_puestos_clean["Departamento"]
)
df_puestos_clean["Nombre de Posición"] = clean_text_series(
    df_puestos_clean["Nombre de Posición"]
)

# Eliminar duplicados basándonos en las llaves (Equivale al FIRSTNONBLANK de DAX)
df_puestos_clean.drop_duplicates(
    subset=["Departamento", "Nombre de Posición"], inplace=True
)

df_jeq_final3_clean = df_jeq_final3.copy()

# Normalizamos las llaves de cruce en la tabla principal
df_jeq_final3_clean["SECCION1"] = clean_text_series(
    df_jeq_final3_clean["SECCION"]
)
df_jeq_final3_clean["PUESTO1"] = clean_text_series(df_jeq_final3_clean["PUESTO"])

df_jeq_final4 = df_jeq_final3_clean.merge(
    df_puestos_clean[["Departamento", "Nombre de Posición", "Grupo_Area"]],
    left_on=["SECCION", "PUESTO"],
    right_on=["Departamento", "Nombre de Posición"],
    how="left",
)
df_jeq_final4.rename(columns={"Grupo_Area": "_GrupoArea"}, inplace=True)

df_secciones_clean = df_secciones.copy()
df_secciones_clean["TIPO"] = clean_text_series(df_secciones_clean["TIPO"])
df_secciones_clean.drop_duplicates(subset=["TIPO"], inplace=True)

df_jeq_final4_clean = df_jeq_final4.copy()
df_jeq_final4_clean["_GrupoArea"] = clean_text_series(df_jeq_final4_clean["_GrupoArea"])

df_jeq_final5 = df_jeq_final4_clean.merge( df_secciones_clean, left_on="_GrupoArea", right_on="TIPO", how="left")

df_jeq_final5["_Tipo"] = np.where(
    df_jeq_final5["_GrupoArea"] == "ADM",
    "Adm",
    np.where(
        df_jeq_final5["TIPO"].isna(), "adm", df_jeq_final5["TIPO"]
    ),
)

df_jeq_final5["_Tienda"] = df_jeq_final5["Tienda"]
df_jeq_final6 = df_jeq_final5.groupby(["_Periodo", "codigo_local", "_Tienda", "_Tipo", "_GrupoArea"])[ "HRS_REAL"].sum().reset_index()

periodo_dt = pd.to_datetime(df_jeq_final6["_Periodo"], format="%Y%m")
cant_dias_mes = periodo_dt.dt.days_in_month

factor_dia = 192 / 28
factor_mes = factor_dia * cant_dias_mes

# 4. Calcular el resultado final (_JEQv2)
df_jeq_final6["JEq"] = df_jeq_final6["HRS_REAL"] / factor_mes

# %%
df_jeq_final5[(df_jeq_final5["_Periodo"]=="202601")].to_excel("revisar2.xlsx")

# %%
df_jeq_final6["_Tipo"].unique()
# Out:
# array(['ABARROTES', 'CAJAS', 'ELECTRO', 'FRESCOS', 'adm', 'INVENTARIOS',
#        'MULTIFUNCIONAL', 'Adm', 'ALMACEN', 'ALMACEN FRESCOS'],
#       dtype=object)

# %% [markdown]
# ### 03 LOAD

# %%
dff = pd.read_parquet(r"C:\Users\eparedes\Intercorp Retail\Productividad PV - VV - EP\02_Productividad\Automatizacion Recalculo CAPO\bk\output\JEq.parquet")

# %%
dff
# Out:
#       _Periodo codigo_local                   _Tienda            _Tipo  \
# 0       202401         1198  1198_Cusco Wanchaq - PVH        ABARROTES
# 1       202401         1198  1198_Cusco Wanchaq - PVH          ALMACEN
# 2       202401         1198  1198_Cusco Wanchaq - PVH  ALMACEN FRESCOS
# 3       202401         1198  1198_Cusco Wanchaq - PVH            CAJAS
# 4       202401         1198  1198_Cusco Wanchaq - PVH          ELECTRO
# ...        ...          ...                       ...              ...
# 23494   202606         X209      X209_Bolognesi - PVE              Adm
# 23495   202606         X209      X209_Bolognesi - PVE      INVENTARIOS
# 23496   202606         X209      X209_Bolognesi - PVE   MULTIFUNCIONAL
# 23497   202606         X210     X210_Santa Cruz - PVE              Adm
# 23498   202606         X210     X210_Santa Cruz - PVE   MULTIFUNCIONAL
#
#             _GrupoArea  HRS_REAL       JEq
# 0            ABARROTES   1339.48  6.301317
# 1              ALMACEN    724.75  3.409442
# 2      ALMACEN FRESCOS    671.73  3.160020
# 3                CAJAS   2007.50  9.443884
# 4              ELECTRO    349.28  1.643118
# ...                ...       ...       ...
# 23494              ADM     52.14  0.253458
# 23495      INVENTARIOS     47.86  0.232653
# 23496   MULTIFUNCIONAL    405.94  1.973319
# 23497              ADM    116.07  0.564229
# 23498   MULTIFUNCIONAL    182.98  0.889486
#
# [23499 rows x 7 columns]
