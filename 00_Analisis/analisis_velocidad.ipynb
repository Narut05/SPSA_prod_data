# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from glob import glob
# Aplicar configuraciones de visualización total de Pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)

import func_gcp as func_gcp

# %%
query = '''
SELECT *
FROM `spsa-operaciones-seg-sd.dst_gestion_operativa.v_velocidad_cajero_opr`
WHERE fecha >= '2025-01-01'
  AND codigo_local = 'P084';
'''

# %%
query2 = 'select * from spsa-operaciones-seg-sd.dst_gestion_operativa.bsc_local_atributos'

# %%
df_velocidad = func_gcp.read_query(query)
# Out:
# d:\Usuarios\SP44812227\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\auth\_default.py:113: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# d:\Usuarios\SP44812227\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\cloud\bigquery\table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %%
df_local = func_gcp.read_query(query2)
# Out:
# d:\Usuarios\SP44812227\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\auth\_default.py:113: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# d:\Usuarios\SP44812227\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\cloud\bigquery\table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %%
df_velocidad["descripcion_terminal"].unique()
# Out:
# array(['Rapida', 'Lineal', None, 'Self check out'], dtype=object)

# %%
df_velocidad["tipo_venta"].unique()
# Out:
# array(['Venta POS', 'Venta Ecommerce', 'Venta CNegocio'], dtype=object)

# %%
df_velocidad.groupby(["nombre_puesto"])["item_escaneados"].sum()

# %%
df_velocidad["nombre_puesto"].unique()
# Out:
# array(['CAJERO 3X4', 'CAJERO 6X1', 'CAJERO 6X1 1ER TURNO',
#        'CAJERO 6X1 2DO TURNO', '', 'CAJERO 5X2', 'CAJERO 5X2 2DO TURNO',
#        'SUPERVISOR DE CAJEROS', 'MULTIFUNCIONAL 5X2 CAMPAÑA',
#        'CAJERO 5X2 1ER TURNO', None, 'CAJERO 3X4 EO', 'CAJERO 5X2 EO',
#        'SUPERVISOR DE CAJEROS 5X2', 'JEFE DE SECCION'], dtype=object)

# %%
cajero = ['CAJERO 3X4', 'CAJERO 6X1', 'CAJERO 6X1 1ER TURNO',
       'CAJERO 6X1 2DO TURNO', 'CAJERO 5X2', 'CAJERO 5X2 2DO TURNO','CAJERO 5X2 1ER TURNO', 'CAJERO 3X4 EO', 'CAJERO 5X2 EO',]

# %%
df_velocidad["unidad_formula"] = df_velocidad["item_escaneados"]
df_velocidad["tiempo_formula"] = df_velocidad["tiempo_escaneo"]

# %%
df_velocidad
# Out:
#             fecha codigo_local  numero_terminal descripcion_terminal  \
# 0      2025-04-14         P084                3               Rapida
# 1      2025-04-14         P084                3               Rapida
# 2      2025-04-14         P084               17               Lineal
# 3      2025-04-14         P084               17               Lineal
# 4      2025-04-14         P084               21               Lineal
# ...           ...          ...              ...                  ...
# 39667  2025-12-12         P084              999                 None
# 39668  2025-12-12         P084              999                 None
# 39669  2025-12-12         P084              999                 None
# 39670  2025-09-18         P084              999                 None
# 39671  2025-09-18         P084              999                 None
#
#        codigo_tipo_venta       tipo_venta codigo_tipo_doc_trx  codigo_cajera  \
# ...
